# %%
import numpy as np

# %%
#Mathematical fnx

#aggregation

arr = np.array( [1, 2, 3, 4, 5])

print(np.sum(arr))
print(np.prod(arr))
print(np.min(arr))
print(np.max(arr))
print(np.argmin(arr))
print(np.argmax(arr))

print(np.mean(arr))
print(np.std(arr))
print(np.median(arr))
print(np.var(arr))
# Out:
# 15
# 120
# 1
# 5
# 0
# 4
# 3.0
# 1.4142135623730951
# 3.0
# 2.0

# %%
#power function
arr = np.array( [1, 2, 3, 4, 5])
print(np.square(arr))
print(np.sqrt(arr))
print(np.pow(arr,3))
# Out:
# [ 1  4  9 16 25]
# [1.         1.41421356 1.73205081 2.         2.23606798]
# [  1   8  27  64 125]

# %%
#log
print(np.log(arr))
print(np.log10(arr))
print(np.log2(arr))
print(np.exp(arr))
# Out:
# [0.         0.69314718 1.09861229 1.38629436 1.60943791]
# [0.         0.30103    0.47712125 0.60205999 0.69897   ]
# [0.         1.         1.5849625  2.         2.32192809]
# [  2.71828183   7.3890561   20.08553692  54.59815003 148.4131591 ]

# %%
#rounding
print(np.round(3.14))
print(np.ceil(3.14))
print(np.floor(3.14))
print(np.trunc(3.14))
# Out:
# 3.0
# 4.0
# 3.0
# 3.0

# %%
arr = np.array([1, 2, -8, 3, 4, -5, 2, -5])

print(np.unique(arr))
print(np.sort(arr))

print(np.abs(arr))
# Out:
# [-8 -5  1  2  3  4]
# [-8 -5 -5  1  2  2  3  4]
# [1 2 8 3 4 5 2 5]

# %%
a = np.random.randint(1,100,15)
a
# Out:
# array([30, 11, 87, 38, 30, 23, 37, 94, 16, 10, 64, 35, 84, 41, 21],
#       dtype=int32)

# %%
# find all indices with value greater than 50

# %%
np.where(a>50)
# Out:
# (array([ 2,  7, 10, 12]),)

# %%
# replace these values with 0

# %%
np.where(a>50,0,a)
# Out:
# array([30, 11,  0, 38, 30, 23, 37,  0, 16, 10,  0, 35,  0, 41, 21],
#       dtype=int32)
