# %%
import numpy as np

# %%
a = np.array([1,2,3,4,np.nan,6])
print(a)
# Out:
# [ 1.  2.  3.  4. nan  6.]

# %%
print(np.isnan(a))
a[~np.isnan(a)]
# Out:
# [False False False False  True False]
# array([1., 2., 3., 4., 6.])
