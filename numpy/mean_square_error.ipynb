# %%
import numpy as np

# %%
actual = np.random.randint(1,50,25)
predicted = np.random.randint(1,50,25)

# %%
print(actual)
print(predicted)
# Out:
# [38 36 20 42  1 23  4 17 16 45 22 11  3 32 42  3 16 18 21  5  9 36 28 17
#  37]
# [35 14  6 33 40 25 45 21 15 19 10 42 15 14 16 37 25  2 19 17 39 11 10 29
#  25]

# %%
def mse(actual, predicted):
    return np.mean((actual - predicted)**2)
print(mse(actual,predicted))
# Out:
# 427.84
