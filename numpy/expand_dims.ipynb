# %%
import numpy as np

# %%
a = np.random.randint(1,100,15)

a.shape
# Out:
# (15,)

# %%
np.expand_dims(a,axis = 1)
# Out:
# array([[96],
#        [ 6],
#        [24],
#        [94],
#        [84],
#        [12],
#        [27],
#        [ 4],
#        [24],
#        [30],
#        [10],
#        [33],
#        [94],
#        [56],
#        [10]], dtype=int32)
